# %% [markdown]
# # Latihan 1

# %%
#gunakan url file ini untuk menjawab latihan part 1
link_boston = "https://github.com/mofdac/-materi-das/blob/main/01.%20Python%20for%20DA/latihan/Boston_Housing.xlsx?raw=true"

# %%
import pandas as pd 
#silahkan di import package lain jika diperlukan

# %%
df_boston = pd.read_excel(link_boston)
df_boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ## 1. Tampilkan Informasi Statistik Seperti Mean, Median,Std, dll dari dataset diatas

# %%
df_boston.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
df_boston['CRIM'].plot(kind='hist')
#df_boston['MEDV'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 2. Apa saja tipe data yang ada dari dataframe diatas

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df_boston.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %% [markdown]
# ## 3.  Terdapat Berapa Kolom di data diatas ?

# %%
# axis0 = baris, axis1=kolom
print(df_boston.shape)
print(df_boston.shape[1])
print(df_boston.shape[0])
# Out:
# (506, 14)
# 14
# 506

# %% [markdown]
# ## 4. Kolom manakah yang memiliki keberagaman paling tinggi (CoV)?

# %%
desc_boston = df_boston.describe().T[['std','mean']]
desc_boston
# Out:
#                 std        mean
# CRIM       8.601545    3.613524
# ZN        23.322453   11.363636
# INDUS      6.860353   11.136779
# CHAS       0.253994    0.069170
# NOX        0.115878    0.554695
# RM         0.702617    6.284634
# AGE       28.148861   68.574901
# DIS        2.105710    3.795043
# RAD        8.707259    9.549407
# TAX      168.537116  408.237154
# PTRATIO    2.164946   18.455534
# B         91.294864  356.674032
# LSTAT      7.141062   12.653063
# MEDV       9.197104   22.532806

# %%
desc_boston['CoV'] = desc_boston['std'] / desc_boston['mean']
highest_cov=
desc_boston.sort_values('CoV', ascending = False)['CoV'].index[0]
# Out:
# 'CHAS'

# %%
var = df_boston.var()
df_var = pd.DataFrame(var, columns=['CoV'])
index = list(range(len(df_var)))
df_index = pd.DataFrame(index)

df_var['variable'] = df_var.index

df_var.index = index
df_var
#df_var.index = index

#index
#df_var.sort_values("CoV", ascending = False)[:5]

# 1,2,4,6,8,9
# Out:
#              CoV variable
# 0      73.986578     CRIM
# 1     543.936814       ZN
# 2      47.064442    INDUS
# 3       0.064513     CHAS
# 4       0.013428      NOX
# 5       0.493671       RM
# 6     792.358399      AGE
# 7       4.434015      DIS
# 8      75.816366      RAD
# 9   28404.759488      TAX
# 10      4.686989  PTRATIO
# 11   8334.752263        B
# 12     50.994760    LSTAT
# 13     84.586724     MEDV

# %% [markdown]
# ## 5. Buatlah DataFrame baru dari data diatas, dengan ketentuan ambil baris dengan nilai kolom "CRIM" 10 Terbesar. Tampilkan hanya Kolom "DIS,MEDV, dan LSTAT" saja

# %%
df_boston_3 = df_boston.sort_values('CRIM', ascending = False)[:11][['DIS','MEDV','LSTAT']]
df_boston_3
# Out:
#         DIS  MEDV  LSTAT
# 380  1.4165  10.4  17.21
# 418  1.8026   8.8  20.62
# 405  1.4254   5.0  22.98
# 410  1.4130  15.0  10.11
# 414  1.6582   7.0  36.98
# 404  1.6074   8.5  27.38
# 398  1.4896   5.0  30.59
# 427  1.8629  10.9  14.52
# 413  1.5894  16.3  20.08
# 417  1.6475  10.4  26.64
# 400  1.5888   5.6  26.77
